# %% [markdown]
# for, while, if 조합을 자유자재로 쓸 수 있도록, 난이도를 [기초 문법] -> [논리 조합] -> [실전 응용] 순서로 배치했습니다.
# 절대 눈으로만 풀지 말고, 직접 코드를 쳐보세요! (정답 코드는 요청하시면 알려드릴게요.)
# 🔥 Level 1. 기초 문법 다지기 (For & If)
# 문제 1. 369 게임의 기초
# 1부터 20까지 숫자를 출력하는데, 3의 배수일 때는 숫자 대신 "짝!"을 출력하세요.
# 출력 예시: 1, 2, 짝!, 4, 5, 짝! ... 19, 20
# 핵심: for, range, % (나머지)

# %% [markdown]
# 문제 2. 카운트다운
# 사용자에게 숫자 하나를 입력받습니다(예: 5).
# 입력받은 숫자부터 1까지 거꾸로 출력하고, 마지막에 "발사!"를 출력하세요.
# 출력 예시: 5, 4, 3, 2, 1, 발사!
# 핵심: for, range(시작, 끝, -1)
# 🔥 Level 2. 흐름 제어하기 (While & Break)

# %% [markdown]
# 문제 3. 커피 자판기
# 커피 1잔 가격은 300원입니다. 자판기에 거스름돈이 1000원밖에 없습니다.
# 사용자에게 돈을 계속 입력받습니다 (input).
# 300원을 받으면 "커피를 줍니다." 출력.
# 300원보다 적으면 "돈이 부족합니다." 출력하고 돈을 돌려주지 않고 다시 입력을 받습니다.
# 300원보다 많으면 거스름돈을 주고 커피를 줍니다.
# 판매를 하다가 자판기 보유 거스름돈(1000원)이 바닥나면(0원 이하가 되면) "영업 종료"를 출력하고 반복문을 멈추세요.
# 핵심: while True, if-elif-else, break, 변수 값 갱신

# %% [markdown]
# 문제 4. 5번만 참아주는 비밀번호
# 비밀번호는 "1234"입니다.
# 사용자에게 비밀번호를 입력받는데, 최대 5번까지만 기회를 줍니다.
# 5번 안에 맞추면 "로그인 성공!" 출력 후 종료.
# 5번 모두 틀리면 "횟수 초과! 접속 불가" 출력 후 종료.
# 핵심: while, count 변수, if, break
# 🔥 Level 3. 데이터 처리하기 (List + Loop)

# %% [markdown]
# 문제 5. 합격자 명단 만들기 (Filtering)
# 학생들의 점수 리스트가 있습니다.
# scores = [55, 90, 89, 76, 30, 100, 67]
# 60점 이상인 학생만 골라서 새로운 리스트 pass_list에 담으세요.
# 단, 100점인 학생은 "우수 장학생"이라고 따로 출력도 해주세요.
# 최종적으로 pass_list를 출력하세요.
# 핵심: for, if, append, 리스트

# %% [markdown]
# 문제 6. 글자수 세기
# 문장: "Python is amazing and easy"
# 이 문장에서 공백(띄어쓰기)을 제외한 글자 수가 총 몇 개인지 구하세요. (len() 함수를 쓰지 말고, 반복문으로 직접 세보세요!)
# 핵심: 문자열 순회(for char in string), if char != " ":, 카운팅
# 🔥 Boss Level. 논리력 끝판왕 (Nested Loop)

# %% [markdown]
# 문제 7. 별 찍기 (계단 만들기)
# 사용자에게 층수(정수)를 입력받아 별(*)을 출력하세요.
# 입력: 3
# 출력:
# code
# Code
# *
# **
# ***
# 핵심: 이중 for문 또는 문자열 곱하기("*" * i)

# %% [markdown]
# 문제 8. 2등 찾기 (정렬 함수 금지)
# numbers = [10, 50, 30, 20, 40]
# 이 리스트에서 sort()나 max()를 쓰지 말고, 로직을 짜서 **두 번째로 큰 수(40)**를 찾아 출력하세요.
# 힌트: '1등 변수'와 '2등 변수' 두 개를 만들어서 비교해가며 갱신해야 합니다.
