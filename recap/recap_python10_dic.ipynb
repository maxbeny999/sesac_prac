# %% [markdown]
# # 딕셔너리
# - 딕셔너리 키와 밸류의 쌍을 순서 없이 저장하는 컨테이너 자료형
# - {} 중괄호로 생성
# - 각 밸류를 , 기준으로 분류

# %%
bands = { "abba" : 10, 
        "scorpions" : 30, 
        "bonjovy" : 40, 
        "queen": 50 }

print(bands)
# Out:
# {'abba': 10, 'scorpions': 30, 'bonjovy': 40, 'queen': 50}

# %% [markdown]
# ##### 빈 딕셔너리

# %%
dictionary = { }

print(f"this is {dictionary}")
# Out:
# this is {}
