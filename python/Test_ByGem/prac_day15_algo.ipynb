# %% [markdown]
# # [Day 15] Algorithm Training
#
# **"좋은 알고리즘은 복잡한 문제를 가장 단순하게 풀어내는 논리입니다."**
#
# 총 3세트의 문제가 준비되어 있습니다. 각 세트는 워밍업(Warm-up) 문제와 메인(Main) 문제로 구성됩니다.
# 워밍업에서 사용한 논리를 메인 문제에 어떻게 적용할지 고민해 보세요.
#
# ---

# %% [markdown]
# ## Set 1. 문자열 처리 (Bronze)
# 문자열을 쪼개고 검사하는 기본기를 다집니다.

# %% [markdown]
# ### Q1. [Warm-up] 모음 개수 세기
# 영단어가 주어질 때, 단어에 포함된 모음('a', 'e', 'i', 'o', 'u')의 개수를 반환하는 함수 `count_vowels(word)`를 작성하세요. 대소문자를 구분하지 않아야 합니다.
#
# * **예시:** `count_vowels("Apple")` -> 2
# * **예시:** `count_vowels("Rhythm")` -> 0

# %%
def count_vowels(word: str) -> int:
    # 여기에 코드를 작성하세요
    pass

# 테스트
print(count_vowels("Apple"))
print(count_vowels("Rhythm"))

# %% [markdown]
# ### Q2. [Main] 팰린드롬(회문) 판별기
# 주어진 문장이 앞으로 읽으나 뒤로 읽으나 같은 문장(팰린드롬)인지 확인하는 함수 `is_palindrome(sentence)`를 작성하세요.
#
# **조건:**
# 1. 띄어쓰기(공백)와 문장부호(',', '.', '!', '?')는 무시합니다.
# 2. 대소문자를 구분하지 않습니다.
#
# * **예시:** `is_palindrome("Was it a cat I saw?")` -> True
# * **예시:** `is_palindrome("Hello World")` -> False
# * **Tip:** 문자열에서 필요한 알파벳만 추출하여 새로운 문자열이나 리스트로 만드는 것이 핵심입니다.

# %%
def is_palindrome(sentence: str) -> bool:
    # 여기에 코드를 작성하세요
    pass

# 테스트
print(is_palindrome("Was it a cat I saw?"))
print(is_palindrome("Hello World"))

# %% [markdown]
# ## Set 2. 수학과 논리 (Bronze)
# 반복문을 활용한 수식 연산의 효율성을 고민합니다.

# %% [markdown]
# ### Q3. [Warm-up] 약수 구하기
# 자연수 `n`이 주어질 때, `n`의 모든 약수를 오름차순으로 담은 리스트를 반환하는 함수 `get_divisors(n)`을 작성하세요.
#
# * **예시:** `get_divisors(12)` -> [1, 2, 3, 4, 6, 12]

# %%
def get_divisors(n: int) -> list:
    # 여기에 코드를 작성하세요
    pass

# 테스트
print(get_divisors(12))

# %% [markdown]
# ### Q4. [Main] 완전수(Perfect Number) 찾기
# 완전수란, 자신을 제외한 약수들의 합이 자기 자신과 같아지는 수를 말합니다. (예: 6의 약수는 1, 2, 3, 6이고, 자신을 제외한 1+2+3 = 6이므로 완전수입니다.)
#
# 자연수 `n`이 주어질 때, 1부터 `n`까지의 숫자 중 **모든 완전수**를 찾아 리스트로 반환하는 함수 `find_perfect_numbers(n)`을 작성하세요.
#
# * **예시:** `find_perfect_numbers(30)` -> [6, 28]
# * **Tip:** Q3에서 만든 로직을 활용해 보세요.

# %%
def find_perfect_numbers(n: int) -> list:
    # 여기에 코드를 작성하세요
    pass

# 테스트
print(find_perfect_numbers(30))

# %% [markdown]
# ## Set 3. 자료구조 응용: Stack (Silver)
# 데이터의 순서를 제어하는 스택(LIFO)의 개념을 실전에 적용합니다.

# %% [markdown]
# ### Q5. [Warm-up] 스택(Stack) 동작 시뮬레이션
# 파이썬의 리스트를 사용하여 스택(Stack)을 구현할 수 있습니다.
# 빈 리스트 `stack = []`이 주어졌을 때, 아래 동작을 순서대로 수행하는 코드를 작성하고 최종 스택의 상태를 출력하세요.
#
# 1. 숫자 10을 넣는다.
# 2. 숫자 20을 넣는다.
# 3. 스택의 맨 위 데이터를 꺼내서 출력한다. (pop)
# 4. 숫자 30을 넣는다.
# 5. 스택이 비어있는지 확인한다. (비어있으면 True, 아니면 False 출력)

# %%
stack = []
# 여기에 코드를 작성하세요


print("최종 상태:", stack)

# %% [markdown]
# ### Q6. [Main] 올바른 괄호 판별 (백준 실버 4 수준)
# 소괄호 '(', ')' 와 중괄호 '{', '}', 대괄호 '[', ']' 로 이루어진 문자열이 주어집니다.
# 이 문자열이 **올바른 괄호 쌍**을 이루고 있는지 확인하는 함수 `is_valid_parentheses(s)`를 작성하세요.
#
# **조건:**
# 1. 열린 괄호는 같은 타입의 닫힌 괄호로 닫혀야 합니다.
# 2. 열린 괄호는 올바른 순서로 닫혀야 합니다.
#
# * **예시:** `is_valid_parentheses("()[]{}")` -> True
# * **예시:** `is_valid_parentheses("([)]")` -> False
# * **예시:** `is_valid_parentheses("{\n  [ ( ) ]\n}")` -> True (공백 무시)
#
# **핵심 로직 힌트:**
# 열린 괄호를 만나면 스택에 넣고, 닫힌 괄호를 만나면 스택에서 하나 꺼내어 짝이 맞는지 확인합니다.

# %%
def is_valid_parentheses(s: str) -> bool:
    # 여기에 코드를 작성하세요
    pass

# 테스트
print(is_valid_parentheses("()[]{}"))  # 예상: True
print(is_valid_parentheses("([)]"))    # 예상: False
