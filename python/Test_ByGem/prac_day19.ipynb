# %% [markdown]
# # 🌅 19일차 데일리 코딩 훈련 - Basic
# * **목표**: 4일간 쉰 뇌와 손가락의 감각을 다시 깨우는 파이썬 기초 체력 단련
# * **주제**: 문자열 파싱, 딕셔너리 안전한 탐색, 리스트 컴프리헨션, 2차원 탐색 (총 6문제)

# %% [markdown]
# ## 문제 1: 지저분한 문자열 청소기 (String 메서드)
# 게시판에서 사용자가 입력한 태그 데이터가 쉼표(,)로 구분되어 들어왔는데, 앞뒤로 쓸데없는 공백이 잔뜩 묻어있습니다.
# 이 문자열을 쪼개고 공백을 제거하여 깔끔한 단어들의 **리스트**로 만들어보세요.
#
# **[출력 예시]**
# `['python', 'fastapi', 'backend', 'async']`
#
# ---
# 💡 **[Hint]** `.split(',')`으로 먼저 쪼갠 뒤, `for`문을 돌면서 `.strip()`을 사용해 빈 리스트에 `.append()` 해보세요.

# %%
raw_tags = " python , fastapi ,  backend  ,   async "
clean_tags = []

# 1. 여기에 코드를 작성하세요.


print(clean_tags)

# %% [markdown]
# ## 문제 2: 딕셔너리 방패 `.get()` 복습
# 4일 전에 Max가 완벽하게 깨우쳤던 바로 그 마법의 메서드입니다!
# 사용자 정보 딕셔너리에서 `phone` 번호를 가져와야 합니다. 하지만 이 데이터에는 전화번호가 누락되어 있습니다.
# 서버가 뻗지 않도록, `.get()`을 사용하여 전화번호가 있으면 그 번호를, 없으면 **"번호 없음"**이라는 문자열을 변수에 담아 출력하게 만들어보세요.

# %%
user_info = {
    "name": "Max",
    "role": "Backend Developer",
    "email": "max@example.com"
    # phone 데이터가 누락된 상태입니다!
}

# 2. 에러가 나지 않도록 .get()을 활용하여 코드를 작성하세요.
phone_number = ""

print(phone_number)

# %% [markdown]
# ## 문제 3: VIP 고객 장바구니 합산 (조건부 누적)
# 고객의 장바구니에 담긴 물건들의 가격 리스트가 주어집니다.
# 이 중 **5만원(50000) 이상인 물건들의 가격만** 골라서 총합을 구하세요.
#
# ---
# 💡 **[Hint]** `for`문으로 리스트를 순회하며, `if`문으로 50000 이상인지 검사한 후 변수에 누적(`+=`)해 보세요.

# %%
cart_prices = [15000, 89000, 5000, 120000, 45000, 60000]
total_vip_price = 0

# 3. 여기에 코드를 작성하세요.


print(total_vip_price)  # 정답: 269000 이 나와야 합니다.

# %% [markdown]
# ## 문제 4: 리스트 안의 딕셔너리 파싱 (List of Dicts)
# API에서 여러 명의 유저 데이터를 리스트 안에 담긴 딕셔너리 형태로 내려주었습니다.
# 이 중에서 **나이가 25세 이상인 유저의 이름(name)만** 뽑아서 새로운 리스트를 만들어보세요.
#
# ---
# 💡 **[Hint]** `for user in users:` 로 순회하면 `user`는 딕셔너리가 됩니다. 여기서 `user['age']`를 검사하면 되겠죠?

# %%
users = [
    {"name": "Alice", "age": 22},
    {"name": "Bob", "age": 28},
    {"name": "Charlie", "age": 25},
    {"name": "David", "age": 20}
]
adult_names = []

# 4. 여기에 코드를 작성하세요.


print(adult_names) # 정답: ['Bob', 'Charlie']

# %% [markdown]
# ## 문제 5: 데이터 빈도수 측정 (딕셔너리 활용)
# 서버 로그에 접속한 IP 주소들이 리스트로 남아있습니다. 어떤 IP가 몇 번 접속했는지 **딕셔너리 형태**로 빈도수를 세어보세요.
#
# ---
# 💡 **[Hint]** `if ip in ip_counts:` 를 활용해 이미 딕셔너리에 존재하는 키인지 확인하고, 없으면 `1`로 초기화, 있으면 `+= 1`을 해줍니다.

# %%
ip_logs = ["192.168.0.1", "10.0.0.1", "192.168.0.1", "192.168.0.1", "10.0.0.1", "8.8.8.8"]
ip_counts = {}

# 5. 여기에 코드를 작성하세요.


print(ip_counts) # 정답: {'192.168.0.1': 3, '10.0.0.1': 2, '8.8.8.8': 1}

# %% [markdown]
# ## 문제 6: 2차원 리스트 탐색 (좌표 찾기)
# 영화관 좌석표가 2차원 리스트로 주어졌습니다. `1`은 예매 완료, `0`은 빈자리입니다.
# 빈자리(`0`)가 있는 **(줄 번호, 칸 번호)** 좌표를 모두 찾아서 리스트에 튜플 형태로 담아보세요.
#
# ---
# 💡 **[Hint]** `for`문을 두 번 중첩해야 합니다. 줄 번호와 칸 번호(인덱스)가 필요하므로 `enumerate()`를 바깥쪽과 안쪽 루프에 모두 적용해 보세요! (18일차 Basic 6번과 동일한 핵심 로직입니다)

# %%
seats = [
    [1, 1, 0, 1],
    [0, 1, 1, 1],
    [1, 0, 0, 1]
]
empty_seats = []

# 6. 여기에 코드를 작성하세요.


print(empty_seats) # 정답: [(0, 2), (1, 0), (2, 1), (2, 2)]
