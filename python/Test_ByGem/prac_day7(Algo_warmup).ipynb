# %% [markdown]
# # 🏋️‍♂️ Day 7 알고리즘 몸풀기 (Warm-Up)
#
# **목표:** 본 게임(백준 문제)에 들어가기 전, 핵심 문법(Deque, Dict, String)을 가볍게 연습합니다.
# 이 문제들을 먼저 풀고 알고리즘 드릴로 넘어가세요.

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ [Deque 기초] 카드2 문제 대비
# > **핵심 스킬:** `deque` 생성과 `popleft()` 사용법 익히기

# %%
# [몸풀기 1-1] 덱(Deque) 만들고 빼기
# 리스트 [10, 20, 30]을 deque로 만들고, 맨 앞에 있는 숫자를 꺼내서 출력하세요.

from collections import deque

data = [10, 20, 30]
# 1. 여기서 deque로 변환하세요 (변수명: queue)

# 2. popleft()를 사용해 10을 꺼내고 출력하세요

# 3. 남은 queue를 출력하세요

# %%
# [몸풀기 1-2] 넣고 빼고 반복하기
# 1부터 5까지 들어있는 덱을 만들고, 빌 때까지 맨 앞 숫자를 꺼내 출력하세요.

from collections import deque

# 1. 1~5가 들어있는 deque 생성

# 2. while 문으로 모두 꺼내서 출력 (popleft 활용)

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ [String & Dict] 단어 공부 대비
# > **핵심 스킬:** 대소문자 변환(`upper`)과 딕셔너리 카운팅

# %%
# [몸풀기 2-1] 대문자로 통일하기
# 입력받은 단어를 무조건 대문자로 변환해서 출력하세요.

word = "baNaNa"
# 1. 대문자로 변환 (upper 사용)

# 출력 예시: BANANA

# %%
# [몸풀기 2-2] 글자 수 세기 (기초)
# 문자열 "AAABBC"가 있습니다. 딕셔너리를 이용해 각 알파벳이 몇 개인지 세어보세요.

text = "AAABBC"
counts = {}

for char in text:
    # 1. 딕셔너리에 없으면 0으로 초기화
    
    # 2. 카운트 +1
    pass # (지우고 작성하세요)

print(counts) # 예상 결과: {'A': 3, 'B': 2, 'C': 1}

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ [Dict Sort] 베스트셀러 대비
# > **핵심 스킬:** 딕셔너리 값 중 최대값(`max`) 찾기 & 정렬(`sort`)

# %%
# [몸풀기 3-1] 가장 많이 팔린 책 찾기 (Max)
# 판매량이 가장 높은 숫자(Max)를 찾아보세요.

sales = {'HarryPotter': 100, 'Hobbit': 50, 'Gatsby': 100}

# 1. value들 중 최대값 찾기 (max 함수 활용)
max_sales = 0 # (수정하세요)

print(max_sales) # 예상 결과: 100

# %%
# [몸풀기 3-2] 사전 순으로 정렬하기 (Sort)
# 책 제목들을 알파벳 순서(사전 순)로 정렬해서 출력하세요.

titles = ['Zelda', 'Apple', 'Banana', 'Canada']

# 1. 오름차순 정렬 (sort 사용)

print(titles) # 예상 결과: ['Apple', 'Banana', 'Canada', 'Zelda']

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ [Replace] 크로아티아 알파벳 대비
# > **핵심 스킬:** 문자열 치환(`replace`)으로 복잡한 문자 없애기

# %%
# [몸풀기 4-1] 특정 단어 삭제하기
# "am"이라는 단어를 찾아서 빈칸("")으로 지워보세요.

sentence = "I am a boy"

# 1. replace를 사용해 "am"을 ""(빈문자열)로 변경
new_sentence = "" # (수정하세요)

print(new_sentence) # 예상 결과: "I  a boy"

# %%
# [몸풀기 4-2] 특수 문자 하나로 퉁치기
# "c=" 라는 덩어리를 별표("*") 한 글자로 바꾸고 길이를 재보세요.

word = "c=c="

# 1. "c=" 를 "*" 로 치환
changed_word = "" # (수정하세요)

# 2. 길이 출력
print(len(changed_word)) # 예상 결과: 2 (별표 2개니까)
